# %% [markdown]
# # 1 Email Validator

# %%
email = input("Enter your email: ")

f = False

for i in email:
    if i == "@":
        f = True
        break
if f and (email.endswith(".com")) or (email.endswith(".org")):
    print("Valid Email")
else:
    print("Invalid Email")
# Out:
# Invalid Email

# %% [markdown]
# # 3 Password Strength Checker

# %%
password = input("Enter Password: ")

upper = False
lower = False
digit = False
special = False

for ch in password:
    if ch.isupper():
        upper = True

    elif ch.islower():
        lower = True
    
    elif ch.isdigit():
        digit = True

    else: 
        special = True

if upper and lower and digit and special:
    print("Strong Password")

else:
    print("Weak Password")

# %% [markdown]
# # 4 Usernaem Generator

# %%
import random
num = random.randint(10,99)



fName = input("Enter your first name: ").lower()
lName = input("Enter your last name: ").lower()

result = ""

for i in range(3):
    result += fName[i]

for j in range(3):
    result += lName[j]

final = result + str(num)
print(final)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 12
#       9 result = ""
#      11 for i in range(3):
# ---> 12     result += fName[i]
#      14 for j in range(3):
#      15     result += lName[j]
#
# IndexError: string index out of range

# %% [markdown]
# # 5 Sms Word Counter

# %%
message = input("Enter your message: ")

word_len = len(message.split())
char_len = len(message)

if char_len > 160:
    print(f"Exceeds 160 Characters (SMS limit).")
else:
    print(f"words = {word_len}, Characters = {char_len}, Status = Within Limit")

# %% [markdown]
# # 6 Remove Duplicates from Contact List

# %%
n = input("Enter dta separated by comma: ").split(",")

remove_dup =[]

for item in n:
    item = item.strip()
    if item not in remove_dup:
        remove_dup.append(item)


print(remove_dup)

# %% [markdown]
# # 7 Detect Suspicious Words in Text (Moderation)

# %%
text = input("Enter a text: ").lower()

banned= ["spam", "scam", "fake"]

for i in banned:
    if i in text:
        print(f"Warning: Suspicious content detected")
        break

else:
    print("No suspicious content")

# %% [markdown]
# # 8 Invoice Code Formatter

# %%
invoice_number = input("Please invoice number: ")

list1 = "INV000"


l = list1 + invoice_number
print(l)

# %% [markdown]
# # 9 Count Hashtags and Mentions(Social Media Analytics)

# %%
posts = input("Enter a posts: ")

hastag = posts.count("#")
mention = posts.count("@")


totaltag = f"Hastags = {hastag} Mentions = {mention}"

print(totaltag)

# %% [markdown]
# # 10. Word Reversal for Data Encryption

# %%
n = input("Enter a sentece: ")

words = n.split()
revers_word = []

for i in words:
    revers_word.append(i[::-1])

print(" ".join(revers_word))
# Out:
# ia si uf
